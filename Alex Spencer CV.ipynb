# %%
# Text Variables
Name = 'ALEXANDRA SPENCER'
Title = 'Data Science & Analytics'
AdditionalDescription = 'Background in law, banking and asset management'
Contact = 'Aberdeen\n0745 468 7978\na.ungureanu-spencer@rgu.ac.uk\nwww.linkedin.com/in/alex-u-spencer\nwww.github.com/alex-spencer03'
ProjectsHeader = 'PORTFOLIO'
ProjectOneTitle = 'ProjectHack 8 Hackathon - 3rd Place'
ProjectOneDesc = '- Power BI dashboard tracking materials prices\n- Scraped and fed to machine learning algorithms for future pricing\n- Created the web-scrapers - available at: https://bit.ly/2P7U7o6'
ProjectTwoTitle = 'IBM Data Science Professional Certificate Final Project'
ProjectTwoDesc = '- Scraped rental property data from Aberdeen Solicitors Property Centre\n- Used a variety of tools to analyse and visualise the data\n- Created maps showing how venue locations impact rental prices\n- Notebook available at: https://bit.ly/3tPzUSC'
ProjectThreeTitle = 'MSc Data Science Application Showcase'
ProjectThreeDesc = '- Jupyter notebook created in support of my RGU MSc Data Science application\n- Showcases four data visualisation and analytics exercises\n- Includes a choropleth map, regression and pipeline objects\n- Notebook available at: https://bit.ly/2Pw7tu0'
WorkHeader = 'EXPERIENCE'
WorkOneTitle = 'Robert Gordon University | Research Assistant'
WorkOneTime = 'Fixed Term Contract | Feb 2021-Present'
WorkOneDesc = '- Project: intellegent system using computer vision and machine learning to detect\n  cardiovascular disease\n- Analyse and understand the existing software and its capabilities\n- Find solutions for floating licence activation and implementation of Python\n  solutions developed by the research team'
WorkTwoTitle = 'Aberdeen Standard Investments | Investor Operations Analyst'
WorkTwoTime = 'Fixed Term Contract | Jul 2018 - Jan 2020'
WorkTwoDesc = '- Fully overhauled a banking oversight process reducing processing time by 84%\n- Initiated a large standing data correction project covering 900+ share classes and\n  3 automated dealing systems through in-depth data and flow analysis\n- Daily analysed trading data and generated executive level reporting\n- Identified error trends in processes and pursued business improvements\n- Supported the Operations Manager with high level flows management'
WorkThreeTitle = 'Lloyds Banking Group | Senior Client Relations Advisor'
WorkThreeTime = 'Permanent | Jan 2014 - Jul 2018'
WorkThreeDesc = '- Client meetings reviewing all retail and business banking products\n- Rebuilt a sensitive client relationship and attracted their £300k+ business within\n  4 months'
EduHeader = 'EDUCATION'
EduOneTitle = 'Robert Gordon University | Master of Science Data Science'
EduOneTime = '2020-2021 (Expected)'
EduTwoTitle = 'Aberdeen University | Master of Laws in Oil and Gas Law'
EduTwoTime = '2011-2012 | Commendation'
EduTwoDesc = '- Specialised in international contracts and environmental law'
EduThreeTitle = 'Babes-Bolyai University | Bachelor of Law'
EduThreeTime = '2007-2011'
SkillsHeader = 'Skills'
SkillsDesc = '- Python, R\n- Data Scraping & Cleaning\n- Data Visualisation\n- Statistical Analysis\n- Machine Learning\n- Computer Vision\n- Jupyter, IBM Watson, RStudio\n- SQL, SSAS, MDX\n- Power Query, Pivot, DAX\n- NoSQL: Neo4j, Cypher\n- Process Improvement\n- Client Management'
ExtrasTitle = 'Certificates'
ExtrasDesc = '- IBM Data Science Professional\n  Certificate (Aug 2020)\n- Yellow Belt Lean Sigma (Aug\n  2019)'
Extras2Title = 'Competitions'
Extras2Desc = 'ProjectHack 8 | 21-22 March 2021\n- 3rd place\n- Video pitch: https://bit.ly/3tRpIcd'
Extras3Title = 'Fun Facts'
Extras3Desc = '- Crochet enthusiast who loves a\n  good book recommendation,\n  barbeques and the outdoors\n- Can hold a golf club\n- Grew up on a military base'
Footer = '>>>This CV was entirely created in Python. Full code available:'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#004E82', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#D9D2E9', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Name, (.02,.96), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.93), weight='regular', fontsize=14)
plt.annotate(AdditionalDescription, (.02, .90), weight='regular', fontsize=12)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=9, color='#000000')
plt.annotate(ProjectsHeader, (.02,.86), weight='bold', fontsize=10, color='#674EA7')
plt.annotate(ProjectOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.78), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.757), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.693), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.672), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.610), weight='regular', fontsize=9)
plt.annotate(WorkHeader, (.02,.57), weight='bold', fontsize=10, color='#674EA7')
plt.annotate(WorkOneTitle, (.02,.54), weight='bold', fontsize=10)
plt.annotate(WorkOneTime, (.02,.524), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.445), weight='regular', fontsize=9)
plt.annotate(WorkTwoTitle, (.02,.42), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.404), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.04,.31), weight='regular', fontsize=9)
plt.annotate(WorkThreeTitle, (.02,.285), weight='bold', fontsize=10)
plt.annotate(WorkThreeTime, (.02,.268), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkThreeDesc, (.04,.22), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.185), weight='bold', fontsize=10, color='#674EA7')
plt.annotate(EduOneTitle, (.02,.155), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.138), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoTitle, (.02,.112), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.095), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoDesc,(.02,.0812), weight='regular', fontsize=9)
plt.annotate(EduThreeTitle, (.02,.057), weight='bold', fontsize=10)
plt.annotate(EduThreeTime, (.02, .041), weight='regular', fontsize=9, alpha=.6)
plt.annotate(Footer, (.02,.01), weight='regular', fontsize=8, alpha=.6)
plt.annotate(SkillsHeader, (.7,.832), weight='bold', fontsize=10, color='#000000')
plt.annotate(SkillsDesc, (.7,.6), weight='regular', fontsize=10, color='#000000')
plt.annotate(ExtrasTitle, (.7,.541), weight='bold', fontsize=10, color='#000000')
plt.annotate(ExtrasDesc, (.7,.459), weight='regular', fontsize=10, color='#000000')
plt.annotate(Extras2Title,(.7,.41), weight='bold', fontsize=10, color='#000000')
plt.annotate(Extras2Desc, (.7, .35), weight='regular', fontsize=10, color='#000000')
plt.annotate(Extras3Title, (.7,.295), weight='bold', fontsize=10, color='#000000')
plt.annotate(Extras3Desc, (.7,.195), weight='regular', fontsize=10, color='#000000')

# save as PDF
plt.savefig('resumeexample.pdf', dpi=300, bbox_inches='tight')
